# %%
import yaml
import numpy as np
from matplotlib import pyplot as plt

# --- Custom Utility Module ---
from mineral_utils import Paleodetector

# %%
mineral_name =  "Halite"  # Must match a key in MINERAL_LIBRARY

sample_mass_kg = 0.002
total_age_kyr = 220.

# --- Continuous Deposition Model Parameters ---
overburden_history = {
    "initial_depth_mwe": 0,
    "rate_overburden_continuous_mwe": 1,
    "density_continuous_g_cm3": 2.17
}

x_bins = np.linspace(0, 50000, 200)
x_mids = x_bins[:-1] + np.diff(x_bins) / 2

# %%
CONFIG = yaml.safe_load(open('Data/basic_config.yaml', 'r'))
MINERAL_LIBRARY = yaml.safe_load(open('Data/mineral_library.yaml', 'r'))

energies = np.array(CONFIG['geant4_energy_bins_gev'][:90])

# %%
mineral_config = MINERAL_LIBRARY.get(mineral_name)

mineral = Paleodetector(mineral_config, total_age_kyr=total_age_kyr, overburden_history=overburden_history)
# Out:
# Interpolating overburden history...
# Initialized Paleodetector: Halite

# %%
total_fission_tracks = mineral.integrate_fission_spectrum(x_bins, sample_mass_kg)
# Out:
# Calculating spontaneous fission background...

# %%
total_neutron_tracks = mineral.integrate_background_neutron_spectrum(x_bins, energies, sample_mass_kg)
# Out:
# /home/cgalelli/Documents/PrimusCode/mineral_utils.py:592: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   total_tracks = np.array([quad(total_tracks_interp, x_bins[i], x_bins[i+1])[0] for i in range(len(x_mids))])
# /home/cgalelli/Documents/PrimusCode/mineral_utils.py:592: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   total_tracks = np.array([quad(total_tracks_interp, x_bins[i], x_bins[i+1])[0] for i in range(len(x_mids))])
