# %%
import os
import shutil
import subprocess
import numpy as np

def run_geant4_simulation(mineral_name, particle_type, n_events, energies_gev):
    """
    Dynamically creates a Geant4 macro file and runs the simulation for a given list of energies.

    Args:
        mineral_name (str): Name of the target material (must be defined in Geant4).
        particle_type (str): Particle type for the gun (e.g., "mu-", "proton").
        n_events (int): Number of primary particles to simulate per energy.
        energies_gev (np.array): Array of energies in GeV to simulate.
    """

    default_output_dir = "./build/output"
    final_output_dir = f"./{mineral_name}_{particle_type}"
    
    if not os.path.exists(default_output_dir):
        os.makedirs(default_output_dir)
    
    if not os.path.exists(final_output_dir):
        os.makedirs(final_output_dir)

    macro_content = f"""# Auto-generated macro file
/control/verbose 0
/run/verbose 1
/tracking/verbose 0

# --- Geometry Setup ---
/testhadr/TargetMat        {mineral_name}
/testhadr/TargetRadius     10 m
/testhadr/TargetLength     200 m

# --- Physics ---
/run/setCut                0.005 mm
/run/initialize

# --- Run Loop ---
/gun/particle {particle_type}
"""

    for energy in energies_gev:
        macro_content += f"\n/gun/energy {energy:.16f} GeV\n"
        macro_content += f"/run/beamOn {n_events}\n"

    macro_filename = "./build/run.in"
    with open(macro_filename, "w") as f:
        f.write(macro_content)

    executable = "./build/Run"
    
    if not os.path.exists(executable):
        print(f"Error: Executable '{executable}' not found. Compile the C++ code first.")
        return

    print(f"Starting Geant4 simulation for {mineral_name} with {len(energies_gev)} energy points...")
    
    try:
        result = subprocess.run([executable, macro_filename], check=True, capture_output=True, text=True)
        print(result.stdout)
        
    except subprocess.CalledProcessError as e:
        print("Error running Geant4:")
        print(e.stderr)
        return
    
    print(f"Simulation finished. Moving files to {final_output_dir}...")
    
    for i, energy in enumerate(energies_gev):
        src_filename = f"outNuclei_{i}.txt"
        src_path = os.path.join(default_output_dir, src_filename)
        
        dst_filename = f"outNuclei_{energy:.6f}.txt"
        dst_path = os.path.join(final_output_dir, dst_filename)
        
        if os.path.exists(src_path):
            shutil.move(src_path, dst_path)
        else:
            print(f"Warning: Expected output file {src_filename} not found.")

    print("All done.")

# %%
energies = np.logspace(-3, 4, 100)[:90]

# %%
run_geant4_simulation("Clinopiroxene", "neutron", 10000, energies)
# Out:
# Starting Geant4 simulation for Clinopiroxene with 90 energy points...
#
# **************************************************************
#  Geant4 version Name: geant4-11-03-patch-02 [MT]   (25-April-2025)
#                        Copyright : Geant4 Collaboration
#                       References : NIM A 506 (2003), 250-303
#                                  : IEEE-TNS 53 (2006), 270-278
#                                  : NIM A 835 (2016), 186-225
#                              WWW : http://geant4.org/
# **************************************************************
#
# ### Target material set to Clinopiroxene
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 0 starts.
# ### Run 0 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.260000s Real=17.429210s Sys=0.190000s [Cpu=94.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 1 starts.
# ### Run 1 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=21.100000s Real=21.314126s Sys=0.210000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 2 starts.
# ### Run 2 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=19.840000s Real=20.038621s Sys=0.200000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 3 starts.
# ### Run 3 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=24.600000s Real=25.123139s Sys=0.280000s [Cpu=99.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 4 starts.
# ### Run 4 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=25.710000s Real=26.278391s Sys=0.310000s [Cpu=99.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 5 starts.
# ### Run 5 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=29.290000s Real=29.587774s Sys=0.290000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 6 starts.
# ### Run 6 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=27.400000s Real=27.661871s Sys=0.260000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 7 starts.
# ### Run 7 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=22.120000s Real=22.305770s Sys=0.180000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 8 starts.
# ### Run 8 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.760000s Real=16.914941s Sys=0.150000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 9 starts.
# ### Run 9 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=19.840000s Real=20.112690s Sys=0.160000s [Cpu=99.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 10 starts.
# ### Run 10 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.940000s Real=19.601048s Sys=0.150000s [Cpu=97.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 11 starts.
# ### Run 11 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.660000s Real=21.732512s Sys=0.150000s [Cpu=95.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 12 starts.
# ### Run 12 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.960000s Real=21.093324s Sys=0.140000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 13 starts.
# ### Run 13 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=19.300000s Real=19.408452s Sys=0.070000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 14 starts.
# ### Run 14 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=15.200000s Real=15.270317s Sys=0.060000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 15 starts.
# ### Run 15 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=14.580000s Real=14.702168s Sys=0.050000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 16 starts.
# ### Run 16 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=15.780000s Real=15.945844s Sys=0.050000s [Cpu=99.3%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 17 starts.
# ### Run 17 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.270000s Real=18.371452s Sys=0.070000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 18 starts.
# ### Run 18 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=21.100000s Real=21.254226s Sys=0.070000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 19 starts.
# ### Run 19 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.940000s Real=21.032845s Sys=0.070000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 20 starts.
# ### Run 20 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.680000s Real=18.777545s Sys=0.080000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 21 starts.
# ### Run 21 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=21.000000s Real=21.391734s Sys=0.070000s [Cpu=98.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 22 starts.
# ### Run 22 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.970000s Real=21.426161s Sys=0.060000s [Cpu=98.2%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 23 starts.
# ### Run 23 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=21.810000s Real=22.237770s Sys=0.070000s [Cpu=98.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 24 starts.
# ### Run 24 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=35.200000s Real=35.474730s Sys=0.090000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 25 starts.
# ### Run 25 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=40.360000s Real=40.559472s Sys=0.110000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 26 starts.
# ### Run 26 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=46.910000s Real=47.334723s Sys=0.090000s [Cpu=99.3%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 27 starts.
# ### Run 27 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=52.640000s Real=52.791612s Sys=0.110000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 28 starts.
# ### Run 28 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=60.370000s Real=60.471519s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 29 starts.
# ### Run 29 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=66.770000s Real=66.854588s Sys=0.070000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 30 starts.
# ### Run 30 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=75.120000s Real=75.244225s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 31 starts.
# ### Run 31 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=84.240000s Real=84.330415s Sys=0.090000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 32 starts.
# ### Run 32 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=93.610000s Real=93.730811s Sys=0.080000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 33 starts.
# ### Run 33 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=106.290000s Real=106.394067s Sys=0.090000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 34 starts.
# ### Run 34 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=122.210000s Real=122.327720s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 35 starts.
# ### Run 35 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=134.580000s Real=134.700087s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 36 starts.
# ### Run 36 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=152.550000s Real=152.886819s Sys=0.120000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 37 starts.
# ### Run 37 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=174.070000s Real=174.207512s Sys=0.120000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 38 starts.
# ### Run 38 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=191.580000s Real=191.788753s Sys=0.110000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 39 starts.
# ### Run 39 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=219.180000s Real=219.915033s Sys=0.140000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 40 starts.
# ### Run 40 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=244.980000s Real=245.211699s Sys=0.140000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 41 starts.
# ### Run 41 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
# ...
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 76 starts.
# ### Run 76 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=30193.720000s Real=30228.010841s Sys=30.320000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 77 starts.
# ### Run 77 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=34788.490000s Real=34792.846330s Sys=0.660000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 78 starts.
# ### Run 78 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=40023.240000s Real=40027.766827s Sys=0.550000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 79 starts.
# ### Run 79 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=49915.400000s Real=49997.568801s Sys=16.830000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 80 starts.
# ### Run 80 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=54003.670000s Real=54026.680042s Sys=2.880000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 81 starts.
# ### Run 81 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=61762.780000s Real=61785.982236s Sys=5.570000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 82 starts.
# ### Run 82 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=72946.720000s Real=73049.715631s Sys=69.970000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 83 starts.
# ### Run 83 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=84569.060000s Real=84643.857120s Sys=25.170000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 84 starts.
# ### Run 84 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=98293.800000s Real=98385.240002s Sys=47.670000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 85 starts.
# ### Run 85 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=108743.560000s Real=108763.959660s Sys=8.440000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 86 starts.
# ### Run 86 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=127566.900000s Real=127627.400004s Sys=24.000000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 87 starts.
# ### Run 87 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=149998.710000s Real=150217.121811s Sys=40.920000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 88 starts.
# ### Run 88 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=171815.360000s Real=171959.753857s Sys=24.750000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Clinopiroxene
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  23.8358 keV    e+  23.3055 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 89 starts.
# ### Run 89 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=192921.340000s Real=192965.747894s Sys=25.840000s [Cpu=100.0%]
# ================== Deleting memory pools ===================
# Number of memory pools allocated: 11; of which, static: 0
# Dynamic pools deleted: 11 / Total memory freed: 7e+02 MB
# ============================================================
#
# Simulation finished. Moving files to ./Clinopiroxene_neutron...
# All done.
