# %%
import os
import shutil
import subprocess
import numpy as np

def run_geant4_simulation(mineral_name, particle_type, n_events, energies_gev):
    """
    Dynamically creates a Geant4 macro file and runs the simulation for a given list of energies.

    Args:
        mineral_name (str): Name of the target material (must be defined in Geant4).
        particle_type (str): Particle type for the gun (e.g., "mu-", "proton").
        n_events (int): Number of primary particles to simulate per energy.
        energies_gev (np.array): Array of energies in GeV to simulate.
    """

    default_output_dir = "./build/output"
    final_output_dir = f"./{mineral_name}_{particle_type}"
    
    if not os.path.exists(default_output_dir):
        os.makedirs(default_output_dir)
    
    if not os.path.exists(final_output_dir):
        os.makedirs(final_output_dir)

    macro_content = f"""# Auto-generated macro file
/control/verbose 0
/run/verbose 1
/tracking/verbose 0

# --- Geometry Setup ---
/testhadr/TargetMat        {mineral_name}
/testhadr/TargetRadius     10 m
/testhadr/TargetLength     200 m

# --- Physics ---
/run/setCut                0.005 mm
/run/initialize

# --- Run Loop ---
/gun/particle {particle_type}
"""

    for energy in energies_gev:
        macro_content += f"\n/gun/energy {energy:.16f} GeV\n"
        macro_content += f"/run/beamOn {n_events}\n"

    macro_filename = "./build/run.in"
    with open(macro_filename, "w") as f:
        f.write(macro_content)

    executable = "./build/Run"
    
    if not os.path.exists(executable):
        print(f"Error: Executable '{executable}' not found. Compile the C++ code first.")
        return

    print(f"Starting Geant4 simulation for {mineral_name} with {len(energies_gev)} energy points...")
    
    try:
        result = subprocess.run([executable, macro_filename], check=True, capture_output=True, text=True)
        print(result.stdout)
        
    except subprocess.CalledProcessError as e:
        print("Error running Geant4:")
        print(e.stderr)
        return
    
    print(f"Simulation finished. Moving files to {final_output_dir}...")
    
    for i, energy in enumerate(energies_gev):
        src_filename = f"outNuclei_{i}.txt"
        src_path = os.path.join(default_output_dir, src_filename)
        
        dst_filename = f"outNuclei_{energy:.6f}.txt"
        dst_path = os.path.join(final_output_dir, dst_filename)
        
        if os.path.exists(src_path):
            shutil.move(src_path, dst_path)
        else:
            print(f"Warning: Expected output file {src_filename} not found.")

    print("All done.")

# %%
energies = np.logspace(-3, 4, 100)

# %%
run_geant4_simulation("Halite", "mu-", 10000, energies)
# Out:
# Starting Geant4 simulation for Halite with 100 energy points...
#
# **************************************************************
#  Geant4 version Name: geant4-11-03-patch-02 [MT]   (25-April-2025)
#                        Copyright : Geant4 Collaboration
#                       References : NIM A 506 (2003), 250-303
#                                  : IEEE-TNS 53 (2006), 270-278
#                                  : NIM A 835 (2016), 186-225
#                              WWW : http://geant4.org/
# **************************************************************
#
# ### Target material already is set to Halite
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 0 starts.
# ### Run 0 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.370000s Real=4.689014s Sys=0.070000s [Cpu=94.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 1 starts.
# ### Run 1 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.270000s Real=4.332520s Sys=0.050000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 2 starts.
# ### Run 2 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=3.670000s Real=3.715585s Sys=0.050000s [Cpu=100.1%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 3 starts.
# ### Run 3 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.020000s Real=4.105571s Sys=0.040000s [Cpu=98.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 4 starts.
# ### Run 4 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.000000s Real=4.194159s Sys=0.070000s [Cpu=97.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 5 starts.
# ### Run 5 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.330000s Real=4.386865s Sys=0.040000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 6 starts.
# ### Run 6 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.690000s Real=4.755343s Sys=0.040000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 7 starts.
# ### Run 7 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.080000s Real=4.142781s Sys=0.060000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 8 starts.
# ### Run 8 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.490000s Real=4.706004s Sys=0.050000s [Cpu=96.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 9 starts.
# ### Run 9 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.520000s Real=4.702922s Sys=0.070000s [Cpu=97.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 10 starts.
# ### Run 10 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.480000s Real=4.676748s Sys=0.040000s [Cpu=96.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 11 starts.
# ### Run 11 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.960000s Real=5.093659s Sys=0.050000s [Cpu=98.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 12 starts.
# ### Run 12 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.880000s Real=4.927545s Sys=0.030000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 13 starts.
# ### Run 13 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=4.980000s Real=5.061293s Sys=0.060000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 14 starts.
# ### Run 14 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=5.220000s Real=5.308077s Sys=0.060000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 15 starts.
# ### Run 15 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=5.510000s Real=5.562400s Sys=0.030000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 16 starts.
# ### Run 16 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=6.090000s Real=6.160864s Sys=0.050000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 17 starts.
# ### Run 17 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=6.340000s Real=6.413834s Sys=0.040000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 18 starts.
# ### Run 18 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=6.660000s Real=6.703158s Sys=0.050000s [Cpu=100.1%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 19 starts.
# ### Run 19 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=7.200000s Real=7.258914s Sys=0.060000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 20 starts.
# ### Run 20 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=8.210000s Real=8.451391s Sys=0.050000s [Cpu=97.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 21 starts.
# ### Run 21 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=8.650000s Real=8.724625s Sys=0.060000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 22 starts.
# ### Run 22 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=10.200000s Real=10.268899s Sys=0.070000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 23 starts.
# ### Run 23 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=10.970000s Real=11.028487s Sys=0.060000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 24 starts.
# ### Run 24 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=12.730000s Real=12.804288s Sys=0.070000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 25 starts.
# ### Run 25 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=14.170000s Real=14.473796s Sys=0.090000s [Cpu=98.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 26 starts.
# ### Run 26 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.780000s Real=16.977733s Sys=0.080000s [Cpu=99.3%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 27 starts.
# ### Run 27 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.220000s Real=18.399191s Sys=0.080000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 28 starts.
# ### Run 28 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.230000s Real=20.393083s Sys=0.100000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 29 starts.
# ### Run 29 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=23.130000s Real=23.472649s Sys=0.100000s [Cpu=99.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 30 starts.
# ### Run 30 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=27.990000s Real=28.221199s Sys=0.120000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 31 starts.
# ### Run 31 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=31.760000s Real=32.029131s Sys=0.100000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 32 starts.
# ### Run 32 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=34.460000s Real=35.510226s Sys=0.290000s [Cpu=97.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 33 starts.
# ### Run 33 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=39.270000s Real=39.595306s Sys=0.110000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 34 starts.
# ### Run 34 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=42.070000s Real=42.276687s Sys=0.140000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 35 starts.
# ### Run 35 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=46.740000s Real=47.069240s Sys=0.220000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 36 starts.
# ### Run 36 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=53.340000s Real=53.841816s Sys=0.210000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 37 starts.
# ### Run 37 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=59.070000s Real=59.355914s Sys=0.110000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 38 starts.
# ### Run 38 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=66.030000s Real=67.075525s Sys=0.420000s [Cpu=99.1%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 39 starts.
# ### Run 39 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=69.670000s Real=70.316824s Sys=0.120000s [Cpu=99.3%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 40 starts.
# ### Run 40 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=75.730000s Real=77.711310s Sys=0.200000s [Cpu=97.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 41 starts.
# ### Run 41 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=80.720000s Real=80.956383s Sys=0.130000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
# ...
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 86 starts.
# ### Run 86 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=8175.650000s Real=8179.681598s Sys=0.640000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 87 starts.
# ### Run 87 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=8722.270000s Real=8727.805076s Sys=0.630000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 88 starts.
# ### Run 88 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=9353.090000s Real=9357.553131s Sys=0.650000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 89 starts.
# ### Run 89 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=10057.980000s Real=10061.384344s Sys=0.840000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 90 starts.
# ### Run 90 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=12022.240000s Real=12619.060088s Sys=14.380000s [Cpu=95.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 91 starts.
# ### Run 91 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=12576.580000s Real=12625.990050s Sys=7.820000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 92 starts.
# ### Run 92 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=13291.580000s Real=13846.115517s Sys=14.160000s [Cpu=96.1%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 93 starts.
# ### Run 93 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=14075.180000s Real=14084.112921s Sys=1.170000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 94 starts.
# ### Run 94 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=14969.400000s Real=14980.463839s Sys=1.140000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 95 starts.
# ### Run 95 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16410.830000s Real=16427.505983s Sys=12.810000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 96 starts.
# ### Run 96 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18384.000000s Real=18388.823541s Sys=0.690000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 97 starts.
# ### Run 97 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20230.090000s Real=20235.936090s Sys=0.730000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 98 starts.
# ### Run 98 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=23127.720000s Real=23133.114993s Sys=1.130000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Halite
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  10.9185 keV    e+  10.7053 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 99 starts.
# ### Run 99 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=24792.790000s Real=24799.639996s Sys=0.690000s [Cpu=100.0%]
# ================== Deleting memory pools ===================
# Number of memory pools allocated: 11; of which, static: 0
# Dynamic pools deleted: 11 / Total memory freed: 1.4e+02 MB
# ============================================================
#
# Simulation finished. Moving files to ./Halite_mu-...
# All done.

# %%
run_geant4_simulation("Halite", "mu+", 10000, energies)
# Out:
# Starting Geant4 simulation for Halite with 100 energy points...

# %%
run_geant4_simulation("Olivine", "mu-", 10000, energies)

# %%
run_geant4_simulation("Olivine", "mu+", 10000, energies)

# %%
run_geant4_simulation("Olivine", "mu-", 10000, energies)
