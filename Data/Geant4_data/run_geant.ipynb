# %%
import os
import shutil
import subprocess
import numpy as np

def run_geant4_simulation(mineral_name, particle_type, n_events, energies_gev):
    """
    Dynamically creates a Geant4 macro file and runs the simulation for a given list of energies.

    Args:
        mineral_name (str): Name of the target material (must be defined in Geant4).
        particle_type (str): Particle type for the gun (e.g., "mu-", "proton").
        n_events (int): Number of primary particles to simulate per energy.
        energies_gev (np.array): Array of energies in GeV to simulate.
    """

    default_output_dir = "./build/output"
    final_output_dir = f"./{mineral_name}_{particle_type}"
    
    if not os.path.exists(default_output_dir):
        os.makedirs(default_output_dir)
    
    if not os.path.exists(final_output_dir):
        os.makedirs(final_output_dir)

    macro_content = f"""# Auto-generated macro file
/control/verbose 0
/run/verbose 1
/tracking/verbose 0

# --- Geometry Setup ---
/testhadr/TargetMat        {mineral_name}
/testhadr/TargetRadius     10 m
/testhadr/TargetLength     200 m

# --- Physics ---
/run/setCut                0.005 mm
/run/initialize

# --- Run Loop ---
/gun/particle {particle_type}
"""

    for energy in energies_gev:
        macro_content += f"\n/gun/energy {energy:.16f} GeV\n"
        macro_content += f"/run/beamOn {n_events}\n"

    macro_filename = "./build/run.in"
    with open(macro_filename, "w") as f:
        f.write(macro_content)

    executable = "./build/Run"
    
    if not os.path.exists(executable):
        print(f"Error: Executable '{executable}' not found. Compile the C++ code first.")
        return

    print(f"Starting Geant4 simulation for {mineral_name} with {len(energies_gev)} energy points...")
    
    try:
        result = subprocess.run([executable, macro_filename], check=True, capture_output=True, text=True)
        print(result.stdout)
        
    except subprocess.CalledProcessError as e:
        print("Error running Geant4:")
        print(e.stderr)
        return
    
    print(f"Simulation finished. Moving files to {final_output_dir}...")
    
    for i, energy in enumerate(energies_gev):
        src_filename = f"outNuclei_{i}.txt"
        src_path = os.path.join(default_output_dir, src_filename)
        
        dst_filename = f"outNuclei_{energy:.6f}.txt"
        dst_path = os.path.join(final_output_dir, dst_filename)
        
        if os.path.exists(src_path):
            shutil.move(src_path, dst_path)
        else:
            print(f"Warning: Expected output file {src_filename} not found.")

    print("All done.")

# %%
energies = np.logspace(-3, 4, 100)

# %%
run_geant4_simulation("Olivine", "neutron", 10000, energies[:90])
# Out:
# Starting Geant4 simulation for Olivine with 90 energy points...
#
# **************************************************************
#  Geant4 version Name: geant4-11-03-patch-02 [MT]   (25-April-2025)
#                        Copyright : Geant4 Collaboration
#                       References : NIM A 506 (2003), 250-303
#                                  : IEEE-TNS 53 (2006), 270-278
#                                  : NIM A 835 (2016), 186-225
#                              WWW : http://geant4.org/
# **************************************************************
#
# ### Target material set to Olivine
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 0 starts.
# ### Run 0 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=13.590000s Real=13.788929s Sys=0.160000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 1 starts.
# ### Run 1 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.200000s Real=17.403358s Sys=0.200000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 2 starts.
# ### Run 2 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.790000s Real=17.014116s Sys=0.230000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 3 starts.
# ### Run 3 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.360000s Real=18.599166s Sys=0.240000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 4 starts.
# ### Run 4 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.970000s Real=17.125404s Sys=0.150000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 5 starts.
# ### Run 5 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=19.750000s Real=19.927602s Sys=0.180000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 6 starts.
# ### Run 6 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.270000s Real=17.392477s Sys=0.120000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 7 starts.
# ### Run 7 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=22.970000s Real=23.078151s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 8 starts.
# ### Run 8 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.350000s Real=17.427937s Sys=0.070000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 9 starts.
# ### Run 9 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.480000s Real=17.845104s Sys=0.090000s [Cpu=98.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 10 starts.
# ### Run 10 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.590000s Real=18.671926s Sys=0.060000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 11 starts.
# ### Run 11 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.820000s Real=18.941315s Sys=0.070000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 12 starts.
# ### Run 12 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=16.020000s Real=16.082793s Sys=0.060000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 13 starts.
# ### Run 13 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=14.020000s Real=14.081866s Sys=0.060000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 14 starts.
# ### Run 14 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=12.830000s Real=12.896622s Sys=0.060000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 15 starts.
# ### Run 15 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=12.080000s Real=12.563898s Sys=0.050000s [Cpu=96.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 16 starts.
# ### Run 16 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.420000s Real=17.672059s Sys=0.040000s [Cpu=98.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 17 starts.
# ### Run 17 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=15.860000s Real=15.904897s Sys=0.050000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 18 starts.
# ### Run 18 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.080000s Real=18.387092s Sys=0.050000s [Cpu=98.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 19 starts.
# ### Run 19 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=17.710000s Real=17.858160s Sys=0.070000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 20 starts.
# ### Run 20 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.590000s Real=18.764062s Sys=0.070000s [Cpu=99.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 21 starts.
# ### Run 21 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=18.750000s Real=18.883594s Sys=0.070000s [Cpu=99.7%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 22 starts.
# ### Run 22 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=20.110000s Real=20.172453s Sys=0.070000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 23 starts.
# ### Run 23 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=21.090000s Real=21.269390s Sys=0.080000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 24 starts.
# ### Run 24 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=32.270000s Real=32.515380s Sys=0.090000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 25 starts.
# ### Run 25 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=37.350000s Real=37.598822s Sys=0.090000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 26 starts.
# ### Run 26 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=42.640000s Real=42.956646s Sys=0.100000s [Cpu=99.5%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 27 starts.
# ### Run 27 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=47.000000s Real=47.380377s Sys=0.090000s [Cpu=99.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 28 starts.
# ### Run 28 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=55.260000s Real=55.395941s Sys=0.100000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 29 starts.
# ### Run 29 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=62.320000s Real=62.443490s Sys=0.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 30 starts.
# ### Run 30 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=71.620000s Real=71.830600s Sys=0.090000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 31 starts.
# ### Run 31 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=77.020000s Real=77.159082s Sys=0.080000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 32 starts.
# ### Run 32 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=86.740000s Real=87.192952s Sys=0.100000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 33 starts.
# ### Run 33 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=97.420000s Real=97.742581s Sys=0.080000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 34 starts.
# ### Run 34 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=111.800000s Real=112.323462s Sys=0.090000s [Cpu=99.6%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 35 starts.
# ### Run 35 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=127.620000s Real=127.707775s Sys=0.080000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 36 starts.
# ### Run 36 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=160.950000s Real=161.374315s Sys=0.090000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 37 starts.
# ### Run 37 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=161.930000s Real=162.118701s Sys=0.140000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 38 starts.
# ### Run 38 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=179.750000s Real=180.219539s Sys=0.110000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 39 starts.
# ### Run 39 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=205.670000s Real=206.108606s Sys=0.140000s [Cpu=99.9%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 40 starts.
# ### Run 40 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=228.250000s Real=228.753449s Sys=0.120000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 41 starts.
# ### Run 41 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=254.080000s Real=254.632669s Sys=0.130000s [Cpu=99.8%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
# ...
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 76 starts.
# ### Run 76 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=30204.850000s Real=30211.556651s Sys=1.130000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 77 starts.
# ### Run 77 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=34757.490000s Real=34777.601918s Sys=11.010000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 78 starts.
# ### Run 78 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=39408.990000s Real=39448.704317s Sys=35.100000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 79 starts.
# ### Run 79 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=45756.860000s Real=45801.662610s Sys=37.120000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 80 starts.
# ### Run 80 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=51867.550000s Real=51879.081240s Sys=5.600000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 81 starts.
# ### Run 81 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=60277.880000s Real=60305.092298s Sys=19.130000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 82 starts.
# ### Run 82 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=69999.580000s Real=70055.897127s Sys=48.740000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 83 starts.
# ### Run 83 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=80512.190000s Real=80589.504018s Sys=69.550000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 84 starts.
# ### Run 84 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=93379.960000s Real=93433.423132s Sys=44.320000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 85 starts.
# ### Run 85 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=107654.250000s Real=107680.869794s Sys=13.530000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 86 starts.
# ### Run 86 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=124598.120000s Real=124635.796270s Sys=25.730000s [Cpu=100.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 87 starts.
# ### Run 87 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=151699.970000s Real=159755.367274s Sys=93.890000s [Cpu=95.0%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 88 starts.
# ### Run 88 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=180311.060000s Real=191192.258351s Sys=111.720000s [Cpu=94.4%]
#
# ========= Table of registered couples ============================
#
# Index : 0     used in the geometry : Yes
#  Material : G4_Galactic
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  990 eV     e+  990 eV  proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# Index : 1     used in the geometry : Yes
#  Material : Olivine
#  Range cuts        :  gamma  5 um     e-  5 um     e+  5 um  proton 5 um
#  Energy thresholds :  gamma  990 eV     e-  21.9666 keV    e+  21.4791 keV proton 500 eV
#  Region(s) which use this couple :
#     DefaultRegionForTheWorld
#
# ==================================================================
#
# ### Run 89 starts.
# ### Run 89 start.
# --> Begin of event: 0
# --> Begin of event: 1000
# --> Begin of event: 2000
# --> Begin of event: 3000
# --> Begin of event: 4000
# --> Begin of event: 5000
# --> Begin of event: 6000
# --> Begin of event: 7000
# --> Begin of event: 8000
# --> Begin of event: 9000
#  Run terminated.
# Run Summary
#   Number of events processed : 10000
#   User=195659.800000s Real=199154.916938s Sys=65.720000s [Cpu=98.3%]
# ================== Deleting memory pools ===================
# Number of memory pools allocated: 11; of which, static: 0
# Dynamic pools deleted: 11 / Total memory freed: 2.6e+02 MB
# ============================================================
#
# Simulation finished. Moving files to ./Olivine_neutron...
# All done.
