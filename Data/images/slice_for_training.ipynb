# %%
import os
from PIL import Image

# --- Configuration ---
INPUT_DIR = '/home/cgalelli/Documents/PrimusCode/Data/images/Apatite2'  # Folder containing your .tif images
OUTPUT_DIR = '/home/cgalelli/Documents/PrimusCode/Data/images/Apatite2/tiles'  # Folder to save the .png tiles
TILE_SIZE = 1024
IMAGES_PER_GROUP = 13

def slice_tif_to_png_tiles(input_dir, output_dir, tile_size, images_per_group):
    """
    Slices all TIFF images in a directory into PNG tiles of a specified size,
    grouping the images for sequential frame numbering.
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Get all TIFF files and sort them for consistent grouping
    tif_files = sorted([f for f in os.listdir(input_dir) if f.lower().endswith(('.tif', '.tiff'))])
    
    print(f"Found {len(tif_files)} TIFF images to process with a group size of {images_per_group}.")

    if len(tif_files)% images_per_group != 0:
        raise ValueError(f"The total number of images ({len(tif_files)}) is not a multiple of images_per_group ({images_per_group}).")
    
    # 2. Iterate over the files in batches (groups)
    file_count = 0
    group_number = 0
    
    for filename in tif_files:
        if file_count % images_per_group == 0:
            # Increment group_number at the start of a new group
            group_number += 1
            
        input_filepath = os.path.join(input_dir, filename)
        base_name = os.path.splitext(filename)[0]
        
        try:
            # Open the TIFF image
            img = Image.open(input_filepath)
            
            # Get image dimensions
            width, height = img.size
            
            # Calculate the number of tiles
            x_tiles = width // tile_size
            y_tiles = height // tile_size
            
            # Handle images that aren't perfectly divisible by TILE_SIZE
            if width % tile_size != 0:
                x_tiles += 1
            if height % tile_size != 0:
                y_tiles += 1

            print(f"Processing {filename} (Group {group_number}): {x_tiles}x{y_tiles} tiles.")
            
            tile_count = 0
            for i in range(x_tiles):
                for j in range(y_tiles):
                    # Calculate the bounding box for the tile (left, top, right, bottom)
                    left = i * tile_size
                    top = j * tile_size
                    right = min(left + tile_size, width)
                    bottom = min(top + tile_size, height)

                    box = (left, top, right, bottom)
                    
                    # Crop the image
                    tile = img.crop(box)
                    
                    # Only save if the tile is the full TILE_SIZE x TILE_SIZE, 
                    # which is what your original code did (though it excludes edge tiles)
                    if tile.width == tile_size and tile.height == tile_size:
                        # Construct output filename with the new format: Frame{n}_{base_name}_{i}_{j}.png
                        # Note: 'n' is represented by 'group_number'
                        tile_filename = f"Frame{group_number}_{base_name}_{i}_{j}.png"
                        output_filepath = os.path.join(output_dir, tile_filename)
                    
                        # Save the tile as a PNG file
                        tile.save(output_filepath, "PNG")
                        tile_count += 1
                    
            print(f"-> Created {tile_count} full-size tiles for {filename}")
            
            file_count += 1

        except Exception as e:
            print(f"Error processing {filename}: {e}")
            
    print(f"\n--- Slicing Complete. Total images processed: {file_count} in {group_number} groups. ---")

# %%
slice_tif_to_png_tiles(INPUT_DIR, OUTPUT_DIR, TILE_SIZE, IMAGES_PER_GROUP)
# Out:
# Found 520 TIFF images to process with a group size of 13.
# Processing Acquisition_14574.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14574.tif
# Processing Acquisition_14575.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14575.tif
# Processing Acquisition_14576.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14576.tif
# Processing Acquisition_14577.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14577.tif
# Processing Acquisition_14578.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14578.tif
# Processing Acquisition_14579.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14579.tif
# Processing Acquisition_14580.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14580.tif
# Processing Acquisition_14581.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14581.tif
# Processing Acquisition_14582.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14582.tif
# Processing Acquisition_14583.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14583.tif
# Processing Acquisition_14584.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14584.tif
# Processing Acquisition_14585.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14585.tif
# Processing Acquisition_14586.tif (Group 1): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14586.tif
# Processing Acquisition_14587.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14587.tif
# Processing Acquisition_14588.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14588.tif
# Processing Acquisition_14589.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14589.tif
# Processing Acquisition_14590.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14590.tif
# Processing Acquisition_14591.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14591.tif
# Processing Acquisition_14592.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14592.tif
# Processing Acquisition_14593.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14593.tif
# Processing Acquisition_14594.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14594.tif
# Processing Acquisition_14595.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14595.tif
# Processing Acquisition_14596.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14596.tif
# Processing Acquisition_14597.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14597.tif
# Processing Acquisition_14598.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14598.tif
# Processing Acquisition_14599.tif (Group 2): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14599.tif
# Processing Acquisition_14600.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14600.tif
# Processing Acquisition_14601.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14601.tif
# Processing Acquisition_14602.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14602.tif
# Processing Acquisition_14603.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14603.tif
# Processing Acquisition_14604.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14604.tif
# Processing Acquisition_14605.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14605.tif
# Processing Acquisition_14606.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14606.tif
# Processing Acquisition_14607.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14607.tif
# Processing Acquisition_14608.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14608.tif
# Processing Acquisition_14609.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14609.tif
# Processing Acquisition_14610.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14610.tif
# Processing Acquisition_14611.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14611.tif
# Processing Acquisition_14612.tif (Group 3): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14612.tif
# Processing Acquisition_14613.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14613.tif
# Processing Acquisition_14614.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14614.tif
# Processing Acquisition_14615.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14615.tif
# Processing Acquisition_14616.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14616.tif
# Processing Acquisition_14617.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14617.tif
# Processing Acquisition_14618.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14618.tif
# Processing Acquisition_14619.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14619.tif
# Processing Acquisition_14620.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14620.tif
# Processing Acquisition_14621.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14621.tif
# Processing Acquisition_14622.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14622.tif
# Processing Acquisition_14623.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14623.tif
# Processing Acquisition_14624.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14624.tif
# Processing Acquisition_14625.tif (Group 4): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14625.tif
# Processing Acquisition_14626.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14626.tif
# Processing Acquisition_14627.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14627.tif
# Processing Acquisition_14628.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14628.tif
# Processing Acquisition_14629.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14629.tif
# Processing Acquisition_14630.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14630.tif
# Processing Acquisition_14631.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14631.tif
# Processing Acquisition_14632.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14632.tif
# Processing Acquisition_14633.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14633.tif
# Processing Acquisition_14634.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14634.tif
# Processing Acquisition_14635.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14635.tif
# Processing Acquisition_14636.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14636.tif
# Processing Acquisition_14637.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14637.tif
# Processing Acquisition_14638.tif (Group 5): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14638.tif
# Processing Acquisition_14639.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14639.tif
# Processing Acquisition_14640.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14640.tif
# Processing Acquisition_14641.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14641.tif
# Processing Acquisition_14642.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14642.tif
# Processing Acquisition_14643.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14643.tif
# Processing Acquisition_14644.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14644.tif
# Processing Acquisition_14645.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14645.tif
# Processing Acquisition_14646.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14646.tif
# Processing Acquisition_14647.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14647.tif
# Processing Acquisition_14648.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14648.tif
# Processing Acquisition_14649.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14649.tif
# Processing Acquisition_14650.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14650.tif
# Processing Acquisition_14651.tif (Group 6): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14651.tif
# Processing Acquisition_14652.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14652.tif
# Processing Acquisition_14653.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14653.tif
# Processing Acquisition_14654.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14654.tif
# Processing Acquisition_14655.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14655.tif
# Processing Acquisition_14656.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14656.tif
# Processing Acquisition_14657.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14657.tif
# Processing Acquisition_14658.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14658.tif
# Processing Acquisition_14659.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14659.tif
# Processing Acquisition_14660.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14660.tif
# Processing Acquisition_14661.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14661.tif
# Processing Acquisition_14662.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14662.tif
# Processing Acquisition_14663.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14663.tif
# Processing Acquisition_14664.tif (Group 7): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14664.tif
# Processing Acquisition_14665.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14665.tif
# Processing Acquisition_14666.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14666.tif
# Processing Acquisition_14667.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14667.tif
# Processing Acquisition_14668.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14668.tif
# Processing Acquisition_14669.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14669.tif
# Processing Acquisition_14670.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14670.tif
# Processing Acquisition_14671.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14671.tif
# Processing Acquisition_14672.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14672.tif
# Processing Acquisition_14673.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14673.tif
# Processing Acquisition_14674.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14674.tif
# Processing Acquisition_14675.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14675.tif
# Processing Acquisition_14676.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14676.tif
# Processing Acquisition_14677.tif (Group 8): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14677.tif
# Processing Acquisition_14678.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14678.tif
# Processing Acquisition_14679.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14679.tif
# Processing Acquisition_14680.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14680.tif
# Processing Acquisition_14681.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14681.tif
# Processing Acquisition_14682.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14682.tif
# Processing Acquisition_14683.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14683.tif
# Processing Acquisition_14684.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14684.tif
# Processing Acquisition_14685.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14685.tif
# Processing Acquisition_14686.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14686.tif
# Processing Acquisition_14687.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14687.tif
# Processing Acquisition_14688.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14688.tif
# Processing Acquisition_14689.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14689.tif
# Processing Acquisition_14690.tif (Group 9): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14690.tif
# Processing Acquisition_14691.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14691.tif
# Processing Acquisition_14692.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14692.tif
# Processing Acquisition_14693.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14693.tif
# Processing Acquisition_14694.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14694.tif
# Processing Acquisition_14695.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14695.tif
# Processing Acquisition_14696.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14696.tif
# Processing Acquisition_14697.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14697.tif
# Processing Acquisition_14698.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14698.tif
# Processing Acquisition_14699.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14699.tif
# Processing Acquisition_14700.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14700.tif
# Processing Acquisition_14701.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14701.tif
# Processing Acquisition_14702.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14702.tif
# Processing Acquisition_14703.tif (Group 10): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14703.tif
# Processing Acquisition_14704.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14704.tif
# Processing Acquisition_14705.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14705.tif
# Processing Acquisition_14706.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14706.tif
# Processing Acquisition_14707.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14707.tif
# Processing Acquisition_14708.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14708.tif
# Processing Acquisition_14709.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14709.tif
# Processing Acquisition_14710.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14710.tif
# Processing Acquisition_14711.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14711.tif
# Processing Acquisition_14712.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14712.tif
# Processing Acquisition_14713.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14713.tif
# Processing Acquisition_14714.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14714.tif
# Processing Acquisition_14715.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14715.tif
# Processing Acquisition_14716.tif (Group 11): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14716.tif
# Processing Acquisition_14717.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14717.tif
# Processing Acquisition_14718.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14718.tif
# Processing Acquisition_14719.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14719.tif
# Processing Acquisition_14720.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14720.tif
# Processing Acquisition_14721.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14721.tif
# Processing Acquisition_14722.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14722.tif
# Processing Acquisition_14723.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14723.tif
# Processing Acquisition_14724.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14724.tif
# Processing Acquisition_14725.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14725.tif
# Processing Acquisition_14726.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14726.tif
# Processing Acquisition_14727.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14727.tif
# Processing Acquisition_14728.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14728.tif
# Processing Acquisition_14729.tif (Group 12): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14729.tif
# Processing Acquisition_14730.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14730.tif
# Processing Acquisition_14731.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14731.tif
# Processing Acquisition_14732.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14732.tif
# Processing Acquisition_14733.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14733.tif
# Processing Acquisition_14734.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14734.tif
# Processing Acquisition_14735.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14735.tif
# Processing Acquisition_14736.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14736.tif
# Processing Acquisition_14737.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14737.tif
# Processing Acquisition_14738.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14738.tif
# Processing Acquisition_14739.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14739.tif
# Processing Acquisition_14740.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14740.tif
# Processing Acquisition_14741.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14741.tif
# Processing Acquisition_14742.tif (Group 13): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14742.tif
# Processing Acquisition_14743.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14743.tif
# Processing Acquisition_14744.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14744.tif
# Processing Acquisition_14745.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14745.tif
# Processing Acquisition_14746.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14746.tif
# Processing Acquisition_14747.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14747.tif
# Processing Acquisition_14748.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14748.tif
# Processing Acquisition_14749.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14749.tif
# Processing Acquisition_14750.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14750.tif
# Processing Acquisition_14751.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14751.tif
# Processing Acquisition_14752.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14752.tif
# Processing Acquisition_14753.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14753.tif
# Processing Acquisition_14754.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14754.tif
# Processing Acquisition_14755.tif (Group 14): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14755.tif
# Processing Acquisition_14756.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14756.tif
# Processing Acquisition_14757.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14757.tif
# Processing Acquisition_14758.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14758.tif
# Processing Acquisition_14759.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14759.tif
# Processing Acquisition_14760.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14760.tif
# Processing Acquisition_14761.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14761.tif
# Processing Acquisition_14762.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14762.tif
# Processing Acquisition_14763.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14763.tif
# Processing Acquisition_14764.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14764.tif
# Processing Acquisition_14765.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14765.tif
# Processing Acquisition_14766.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14766.tif
# Processing Acquisition_14767.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14767.tif
# Processing Acquisition_14768.tif (Group 15): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14768.tif
# Processing Acquisition_14769.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14769.tif
# Processing Acquisition_14770.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14770.tif
# Processing Acquisition_14771.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14771.tif
# Processing Acquisition_14772.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14772.tif
# Processing Acquisition_14773.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14773.tif
# Processing Acquisition_14774.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14774.tif
# Processing Acquisition_14775.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14775.tif
# Processing Acquisition_14776.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14776.tif
# Processing Acquisition_14777.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14777.tif
# Processing Acquisition_14778.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14778.tif
# Processing Acquisition_14779.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14779.tif
# Processing Acquisition_14780.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14780.tif
# Processing Acquisition_14781.tif (Group 16): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14781.tif
# Processing Acquisition_14782.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14782.tif
# Processing Acquisition_14783.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14783.tif
# Processing Acquisition_14784.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14784.tif
# Processing Acquisition_14785.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14785.tif
# Processing Acquisition_14786.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14786.tif
# Processing Acquisition_14787.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14787.tif
# Processing Acquisition_14788.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14788.tif
# Processing Acquisition_14789.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14789.tif
# Processing Acquisition_14790.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14790.tif
# Processing Acquisition_14791.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14791.tif
# Processing Acquisition_14792.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14792.tif
# Processing Acquisition_14793.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14793.tif
# Processing Acquisition_14794.tif (Group 17): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14794.tif
# Processing Acquisition_14795.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14795.tif
# Processing Acquisition_14796.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14796.tif
# Processing Acquisition_14797.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14797.tif
# Processing Acquisition_14798.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14798.tif
# Processing Acquisition_14799.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14799.tif
# Processing Acquisition_14800.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14800.tif
# Processing Acquisition_14801.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14801.tif
# Processing Acquisition_14802.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14802.tif
# Processing Acquisition_14803.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14803.tif
# Processing Acquisition_14804.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14804.tif
# Processing Acquisition_14805.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14805.tif
# Processing Acquisition_14806.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14806.tif
# Processing Acquisition_14807.tif (Group 18): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14807.tif
# Processing Acquisition_14808.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14808.tif
# Processing Acquisition_14809.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14809.tif
# Processing Acquisition_14810.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14810.tif
# Processing Acquisition_14811.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14811.tif
# Processing Acquisition_14812.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14812.tif
# Processing Acquisition_14813.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14813.tif
# Processing Acquisition_14814.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14814.tif
# Processing Acquisition_14815.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14815.tif
# Processing Acquisition_14816.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14816.tif
# Processing Acquisition_14817.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14817.tif
# Processing Acquisition_14818.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14818.tif
# Processing Acquisition_14819.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14819.tif
# Processing Acquisition_14820.tif (Group 19): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14820.tif
# Processing Acquisition_14821.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14821.tif
# Processing Acquisition_14822.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14822.tif
# Processing Acquisition_14823.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14823.tif
# Processing Acquisition_14824.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14824.tif
# Processing Acquisition_14825.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14825.tif
# Processing Acquisition_14826.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14826.tif
# Processing Acquisition_14827.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14827.tif
# Processing Acquisition_14828.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14828.tif
# Processing Acquisition_14829.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14829.tif
# Processing Acquisition_14830.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14830.tif
# Processing Acquisition_14831.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14831.tif
# Processing Acquisition_14832.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14832.tif
# Processing Acquisition_14833.tif (Group 20): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14833.tif
# Processing Acquisition_14834.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14834.tif
# Processing Acquisition_14835.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14835.tif
# Processing Acquisition_14836.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14836.tif
# Processing Acquisition_14837.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14837.tif
# Processing Acquisition_14838.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14838.tif
# Processing Acquisition_14839.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14839.tif
# Processing Acquisition_14840.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14840.tif
# Processing Acquisition_14841.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14841.tif
# Processing Acquisition_14842.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14842.tif
# Processing Acquisition_14843.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14843.tif
# Processing Acquisition_14844.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14844.tif
# Processing Acquisition_14845.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14845.tif
# Processing Acquisition_14846.tif (Group 21): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14846.tif
# Processing Acquisition_14847.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14847.tif
# Processing Acquisition_14848.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14848.tif
# Processing Acquisition_14849.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14849.tif
# Processing Acquisition_14850.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14850.tif
# Processing Acquisition_14851.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14851.tif
# Processing Acquisition_14852.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14852.tif
# Processing Acquisition_14853.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14853.tif
# Processing Acquisition_14854.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14854.tif
# Processing Acquisition_14855.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14855.tif
# Processing Acquisition_14856.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14856.tif
# Processing Acquisition_14857.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14857.tif
# Processing Acquisition_14858.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14858.tif
# Processing Acquisition_14859.tif (Group 22): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14859.tif
# Processing Acquisition_14860.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14860.tif
# Processing Acquisition_14861.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14861.tif
# Processing Acquisition_14862.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14862.tif
# Processing Acquisition_14863.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14863.tif
# Processing Acquisition_14864.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14864.tif
# Processing Acquisition_14865.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14865.tif
# Processing Acquisition_14866.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14866.tif
# Processing Acquisition_14867.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14867.tif
# Processing Acquisition_14868.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14868.tif
# Processing Acquisition_14869.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14869.tif
# Processing Acquisition_14870.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14870.tif
# Processing Acquisition_14871.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14871.tif
# Processing Acquisition_14872.tif (Group 23): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14872.tif
# Processing Acquisition_14873.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14873.tif
# Processing Acquisition_14874.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14874.tif
# Processing Acquisition_14875.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14875.tif
# Processing Acquisition_14876.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14876.tif
# Processing Acquisition_14877.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14877.tif
# Processing Acquisition_14878.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14878.tif
# Processing Acquisition_14879.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14879.tif
# Processing Acquisition_14880.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14880.tif
# Processing Acquisition_14881.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14881.tif
# Processing Acquisition_14882.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14882.tif
# Processing Acquisition_14883.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14883.tif
# Processing Acquisition_14884.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14884.tif
# Processing Acquisition_14885.tif (Group 24): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14885.tif
# Processing Acquisition_14886.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14886.tif
# Processing Acquisition_14887.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14887.tif
# Processing Acquisition_14888.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14888.tif
# Processing Acquisition_14889.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14889.tif
# Processing Acquisition_14890.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14890.tif
# Processing Acquisition_14891.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14891.tif
# Processing Acquisition_14892.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14892.tif
# Processing Acquisition_14893.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14893.tif
# Processing Acquisition_14894.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14894.tif
# Processing Acquisition_14895.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14895.tif
# Processing Acquisition_14896.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14896.tif
# Processing Acquisition_14897.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14897.tif
# Processing Acquisition_14898.tif (Group 25): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14898.tif
# Processing Acquisition_14899.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14899.tif
# Processing Acquisition_14900.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14900.tif
# Processing Acquisition_14901.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14901.tif
# Processing Acquisition_14902.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14902.tif
# Processing Acquisition_14903.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14903.tif
# Processing Acquisition_14904.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14904.tif
# Processing Acquisition_14905.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14905.tif
# Processing Acquisition_14906.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14906.tif
# Processing Acquisition_14907.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14907.tif
# Processing Acquisition_14908.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14908.tif
# Processing Acquisition_14909.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14909.tif
# Processing Acquisition_14910.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14910.tif
# Processing Acquisition_14911.tif (Group 26): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14911.tif
# Processing Acquisition_14912.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14912.tif
# Processing Acquisition_14913.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14913.tif
# Processing Acquisition_14914.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14914.tif
# Processing Acquisition_14915.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14915.tif
# Processing Acquisition_14916.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14916.tif
# Processing Acquisition_14917.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14917.tif
# Processing Acquisition_14918.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14918.tif
# Processing Acquisition_14919.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14919.tif
# Processing Acquisition_14920.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14920.tif
# Processing Acquisition_14921.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14921.tif
# Processing Acquisition_14922.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14922.tif
# Processing Acquisition_14923.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14923.tif
# Processing Acquisition_14924.tif (Group 27): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14924.tif
# Processing Acquisition_14925.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14925.tif
# Processing Acquisition_14926.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14926.tif
# Processing Acquisition_14927.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14927.tif
# Processing Acquisition_14928.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14928.tif
# Processing Acquisition_14929.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14929.tif
# Processing Acquisition_14930.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14930.tif
# Processing Acquisition_14931.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14931.tif
# Processing Acquisition_14932.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14932.tif
# Processing Acquisition_14933.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14933.tif
# Processing Acquisition_14934.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14934.tif
# Processing Acquisition_14935.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14935.tif
# Processing Acquisition_14936.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14936.tif
# Processing Acquisition_14937.tif (Group 28): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14937.tif
# Processing Acquisition_14938.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14938.tif
# Processing Acquisition_14939.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14939.tif
# Processing Acquisition_14940.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14940.tif
# Processing Acquisition_14941.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14941.tif
# Processing Acquisition_14942.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14942.tif
# Processing Acquisition_14943.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14943.tif
# Processing Acquisition_14944.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14944.tif
# Processing Acquisition_14945.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14945.tif
# Processing Acquisition_14946.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14946.tif
# Processing Acquisition_14947.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14947.tif
# Processing Acquisition_14948.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14948.tif
# Processing Acquisition_14949.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14949.tif
# Processing Acquisition_14950.tif (Group 29): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14950.tif
# Processing Acquisition_14951.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14951.tif
# Processing Acquisition_14952.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14952.tif
# Processing Acquisition_14953.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14953.tif
# Processing Acquisition_14954.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14954.tif
# Processing Acquisition_14955.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14955.tif
# Processing Acquisition_14956.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14956.tif
# Processing Acquisition_14957.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14957.tif
# Processing Acquisition_14958.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14958.tif
# Processing Acquisition_14959.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14959.tif
# Processing Acquisition_14960.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14960.tif
# Processing Acquisition_14961.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14961.tif
# Processing Acquisition_14962.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14962.tif
# Processing Acquisition_14963.tif (Group 30): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14963.tif
# Processing Acquisition_14964.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14964.tif
# Processing Acquisition_14965.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14965.tif
# Processing Acquisition_14966.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14966.tif
# Processing Acquisition_14967.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14967.tif
# Processing Acquisition_14968.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14968.tif
# Processing Acquisition_14969.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14969.tif
# Processing Acquisition_14970.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14970.tif
# Processing Acquisition_14971.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14971.tif
# Processing Acquisition_14972.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14972.tif
# Processing Acquisition_14973.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14973.tif
# Processing Acquisition_14974.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14974.tif
# Processing Acquisition_14975.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14975.tif
# Processing Acquisition_14976.tif (Group 31): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14976.tif
# Processing Acquisition_14977.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14977.tif
# Processing Acquisition_14978.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14978.tif
# Processing Acquisition_14979.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14979.tif
# Processing Acquisition_14980.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14980.tif
# Processing Acquisition_14981.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14981.tif
# Processing Acquisition_14982.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14982.tif
# Processing Acquisition_14983.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14983.tif
# Processing Acquisition_14984.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14984.tif
# Processing Acquisition_14985.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14985.tif
# Processing Acquisition_14986.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14986.tif
# Processing Acquisition_14987.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14987.tif
# Processing Acquisition_14988.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14988.tif
# Processing Acquisition_14989.tif (Group 32): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14989.tif
# Processing Acquisition_14990.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14990.tif
# Processing Acquisition_14991.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14991.tif
# Processing Acquisition_14992.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14992.tif
# Processing Acquisition_14993.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14993.tif
# Processing Acquisition_14994.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14994.tif
# Processing Acquisition_14995.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14995.tif
# Processing Acquisition_14996.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14996.tif
# Processing Acquisition_14997.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14997.tif
# Processing Acquisition_14998.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14998.tif
# Processing Acquisition_14999.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_14999.tif
# Processing Acquisition_15000.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15000.tif
# Processing Acquisition_15001.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15001.tif
# Processing Acquisition_15002.tif (Group 33): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15002.tif
# Processing Acquisition_15003.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15003.tif
# Processing Acquisition_15004.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15004.tif
# Processing Acquisition_15005.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15005.tif
# Processing Acquisition_15006.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15006.tif
# Processing Acquisition_15007.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15007.tif
# Processing Acquisition_15008.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15008.tif
# Processing Acquisition_15009.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15009.tif
# Processing Acquisition_15010.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15010.tif
# Processing Acquisition_15011.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15011.tif
# Processing Acquisition_15012.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15012.tif
# Processing Acquisition_15013.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15013.tif
# Processing Acquisition_15014.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15014.tif
# Processing Acquisition_15015.tif (Group 34): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15015.tif
# Processing Acquisition_15016.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15016.tif
# Processing Acquisition_15017.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15017.tif
# Processing Acquisition_15018.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15018.tif
# Processing Acquisition_15019.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15019.tif
# Processing Acquisition_15020.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15020.tif
# Processing Acquisition_15021.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15021.tif
# Processing Acquisition_15022.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15022.tif
# Processing Acquisition_15023.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15023.tif
# Processing Acquisition_15024.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15024.tif
# Processing Acquisition_15025.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15025.tif
# Processing Acquisition_15026.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15026.tif
# Processing Acquisition_15027.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15027.tif
# Processing Acquisition_15028.tif (Group 35): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15028.tif
# Processing Acquisition_15029.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15029.tif
# Processing Acquisition_15030.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15030.tif
# Processing Acquisition_15031.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15031.tif
# Processing Acquisition_15032.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15032.tif
# Processing Acquisition_15033.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15033.tif
# Processing Acquisition_15034.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15034.tif
# Processing Acquisition_15035.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15035.tif
# Processing Acquisition_15036.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15036.tif
# Processing Acquisition_15037.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15037.tif
# Processing Acquisition_15038.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15038.tif
# Processing Acquisition_15039.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15039.tif
# Processing Acquisition_15040.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15040.tif
# Processing Acquisition_15041.tif (Group 36): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15041.tif
# Processing Acquisition_15042.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15042.tif
# Processing Acquisition_15043.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15043.tif
# Processing Acquisition_15044.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15044.tif
# Processing Acquisition_15045.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15045.tif
# Processing Acquisition_15046.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15046.tif
# Processing Acquisition_15047.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15047.tif
# Processing Acquisition_15048.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15048.tif
# Processing Acquisition_15049.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15049.tif
# Processing Acquisition_15050.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15050.tif
# Processing Acquisition_15051.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15051.tif
# Processing Acquisition_15052.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15052.tif
# Processing Acquisition_15053.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15053.tif
# Processing Acquisition_15054.tif (Group 37): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15054.tif
# Processing Acquisition_15055.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15055.tif
# Processing Acquisition_15056.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15056.tif
# Processing Acquisition_15057.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15057.tif
# Processing Acquisition_15058.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15058.tif
# Processing Acquisition_15059.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15059.tif
# Processing Acquisition_15060.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15060.tif
# Processing Acquisition_15061.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15061.tif
# Processing Acquisition_15062.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15062.tif
# Processing Acquisition_15063.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15063.tif
# Processing Acquisition_15064.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15064.tif
# Processing Acquisition_15065.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15065.tif
# Processing Acquisition_15066.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15066.tif
# Processing Acquisition_15067.tif (Group 38): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15067.tif
# Processing Acquisition_15068.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15068.tif
# Processing Acquisition_15069.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15069.tif
# Processing Acquisition_15070.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15070.tif
# Processing Acquisition_15071.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15071.tif
# Processing Acquisition_15072.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15072.tif
# Processing Acquisition_15073.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15073.tif
# Processing Acquisition_15074.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15074.tif
# Processing Acquisition_15075.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15075.tif
# Processing Acquisition_15076.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15076.tif
# Processing Acquisition_15077.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15077.tif
# Processing Acquisition_15078.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15078.tif
# Processing Acquisition_15079.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15079.tif
# Processing Acquisition_15080.tif (Group 39): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15080.tif
# Processing Acquisition_15081.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15081.tif
# Processing Acquisition_15082.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15082.tif
# Processing Acquisition_15083.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15083.tif
# Processing Acquisition_15084.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15084.tif
# Processing Acquisition_15085.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15085.tif
# Processing Acquisition_15086.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15086.tif
# Processing Acquisition_15087.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15087.tif
# Processing Acquisition_15088.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15088.tif
# Processing Acquisition_15089.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15089.tif
# Processing Acquisition_15090.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15090.tif
# Processing Acquisition_15091.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15091.tif
# Processing Acquisition_15092.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15092.tif
# Processing Acquisition_15093.tif (Group 40): 5x3 tiles.
# -> Created 8 full-size tiles for Acquisition_15093.tif
#
# --- Slicing Complete. Total images processed: 520 in 40 groups. ---
